# %%
import pandas as pd

df = pd.read_csv(r'C:/Users/gougo/Documents/Twente/1B/Data science/Project/summary_covid_375.csv')
df.shape
df
# Out:
#      Unnamed: 0  PATIENT_ID              RE_DATE  age  gender  \
# 0             1           1  2020-02-08 20:28:15   73       1
# 1             2           2  2020-02-10 19:30:20   61       1
# 2             3           3  2020-01-28 10:14:06   70       2
# 3             4           4  2020-02-06 03:11:25   74       1
# 4             5           5  2020-02-07 16:26:37   29       2
# ..          ...         ...                  ...  ...     ...
# 370         371         371  2020-02-04 22:08:40   63       1
# 371         372         372  2020-02-10 04:04:32   79       1
# 372         373         373  2020-02-12 12:03:20   61       2
# 373         374         374  2020-02-05 04:46:09   33       1
# 374         375         375  2020-02-12 09:56:07   68       1
#
#           Admission time       Discharge time  outcome  \
# 0    2020-01-30 22:12:47  2020-02-17 12:40:09        0
# 1    2020-02-04 21:39:03  2020-02-19 12:59:01        0
# 2    2020-01-23 10:59:36  2020-02-08 17:52:31        0
# 3    2020-01-31 23:03:59  2020-02-18 12:59:12        0
# 4    2020-02-01 20:59:54  2020-02-18 10:33:06        0
# ..                   ...                  ...      ...
# 370  2020-02-04 11:51:01  2020-02-05 19:58:05        1
# 371  2020-02-05 17:52:06  2020-02-16 10:45:40        1
# 372  2020-02-12 03:07:48  2020-02-14 18:47:23        1
# 373  2020-02-03 22:16:30  2020-02-08 10:47:24        1
# 374  2020-02-08 23:25:01  2020-02-19 01:31:58        1
#
#      Hypersensitive cardiac troponinI  hemoglobin  ...  \
# 0                           19.900000  133.200000  ...
# 1                            6.900000  145.750000  ...
# 2                                 NaN  115.666667  ...
# 3                            4.800000   98.000000  ...
# 4                            5.600000  128.000000  ...
# ..                                ...         ...  ...
# 370                       1741.500000  143.000000  ...
# 371                         30.716667  118.700000  ...
# 372                        124.800000  100.000000  ...
# 373                        372.400000  119.000000  ...
# 374                         48.050000  163.000000  ...
#
#      mean corpuscular hemoglobin  Activation of partial thromboplastin time  \
# 0                      32.120000                                  38.400000
# 1                      32.000000                                  39.150000
# 2                      31.833333                                  34.800000
# 3                      41.725000                                        NaN
# 4                      29.866667                                        NaN
# ..                           ...                                        ...
# 370                    30.400000                                  43.800000
# 371                    30.010000                                  47.816667
# 372                    27.600000                                  36.700000
# 373                    30.150000                                  38.700000
# 374                    31.550000                                  40.600000
#
#      Hypersensitive c-reactive protein  HIV antibody quantification  \
# 0                            16.433333                         0.09
# 1                            27.400000                          NaN
# 2                            22.950000                         0.10
# 3                            61.350000                         0.11
# 4                             3.900000                         0.08
# ..                                 ...                          ...
# 370                         152.000000                          NaN
# 371                         232.187500                         0.06
# 372                         205.800000                          NaN
# 373                         109.800000                         0.09
# 374                         162.750000                         0.08
#
#      serum sodium  thrombocytocrit   ESR  glutamic-pyruvic transaminase  \
# 0      140.540000         0.170000  41.0                      29.200000
# 1      138.225000         0.317500  40.0                      29.000000
# 2      139.766667         0.240000  47.5                      56.666667
# 3      141.050000         0.207500  72.0                      23.000000
# 4      141.900000         0.316667  13.0                      15.000000
# ..            ...              ...   ...                            ...
# 370    135.800000         0.160000  19.0                      31.000000
# 371    153.636364         0.172000  93.0                      82.444444
# 372    141.600000         0.180000   NaN                       9.000000
# 373    160.400000         0.130000  19.0                    1061.000000
# 374    135.600000         0.240000  39.0                      17.666667
#
#            eGFR  creatinine
# 0     66.700000   99.000000
# 1     90.400000   79.250000
# 2     83.933333   63.666667
# 3     78.100000   84.500000
# 4    121.400000   56.000000
# ..          ...         ...
# 370   88.600000   81.000000
# 371   16.818182  297.363636
# 372  101.300000   47.000000
# 373   80.933333  109.333333
# 374   76.500000   91.000000
#
# [375 rows x 82 columns]

# %%
#drop collumns that have more NA's than our thereshold
df2 = df.dropna(thresh= len(df) - len(df)*0.06, axis=1 )
df2.shape
df2.head()
# Out:
#    Unnamed: 0  PATIENT_ID              RE_DATE  age  gender  \
# 0           1           1  2020-02-08 20:28:15   73       1
# 1           2           2  2020-02-10 19:30:20   61       1
# 2           3           3  2020-01-28 10:14:06   70       2
# 3           4           4  2020-02-06 03:11:25   74       1
# 4           5           5  2020-02-07 16:26:37   29       2
#
#         Admission time       Discharge time  outcome  hemoglobin  \
# 0  2020-01-30 22:12:47  2020-02-17 12:40:09        0  133.200000
# 1  2020-02-04 21:39:03  2020-02-19 12:59:01        0  145.750000
# 2  2020-01-23 10:59:36  2020-02-08 17:52:31        0  115.666667
# 3  2020-01-31 23:03:59  2020-02-18 12:59:12        0   98.000000
# 4  2020-02-01 20:59:54  2020-02-18 10:33:06        0  128.000000
#
#    Serum chloride  ...  monocytes count   globulin  γ-glutamyl transpeptidase  \
# 0         100.220  ...         0.614000  32.380000                  33.000000
# 1          99.275  ...         0.495000  35.650000                  46.000000
# 2         101.400  ...         0.343333  30.466667                  42.666667
# 3         101.950  ...         0.515000  31.650000                  14.500000
# 4         100.950  ...         0.440000  30.450000                  20.000000
#
#    basophil count(#)  mean corpuscular hemoglobin  \
# 0           0.016000                    32.120000
# 1           0.017500                    32.000000
# 2           0.006667                    31.833333
# 3           0.012500                    41.725000
# 4           0.023333                    29.866667
#
#    Hypersensitive c-reactive protein  serum sodium  \
# 0                          16.433333    140.540000
# 1                          27.400000    138.225000
# 2                          22.950000    139.766667
# 3                          61.350000    141.050000
# 4                           3.900000    141.900000
#
#    glutamic-pyruvic transaminase        eGFR  creatinine
# 0                      29.200000   66.700000   99.000000
# 1                      29.000000   90.400000   79.250000
# 2                      56.666667   83.933333   63.666667
# 3                      23.000000   78.100000   84.500000
# 4                      15.000000  121.400000   56.000000
#
# [5 rows x 49 columns]

# %%
#counting the 
count_nan = len(df2) - df2.count()
count_nan
# Out:
# Unnamed: 0                                    0
# PATIENT_ID                                    0
# RE_DATE                                      14
# age                                           0
# gender                                        0
# Admission time                                0
# Discharge time                                0
# outcome                                       0
# hemoglobin                                   19
# Serum chloride                               21
# eosinophils(%)                               19
# Alkaline phosphatase                         19
# albumin                                      19
# basophil(%)                                  19
# Total bilirubin                              19
# Platelet count                               19
# monocytes(%)                                 19
# indirect bilirubin                           20
# neutrophils(%)                               19
# total protein                                19
# mean corpuscular volume                      19
# hematocrit                                   19
# White blood cell count                       18
# mean corpuscular hemoglobin concentration    19
# Urea                                         19
# lymphocyte count                             19
# Red blood cell count                         18
# Eosinophil count                             19
# Corrected calcium                            22
# Serum potassium                              21
# neutrophils count                            19
# Direct bilirubin                             19
# (%)lymphocyte                                19
# Total cholesterol                            19
# aspartate aminotransferase                   19
# Uric acid                                    19
# HCO3-                                        19
# calcium                                      21
# Lactate dehydrogenase                        19
# monocytes count                              19
# globulin                                     19
# γ-glutamyl transpeptidase                    19
# basophil count(#)                            19
# mean corpuscular hemoglobin                  19
# Hypersensitive c-reactive protein            22
# serum sodium                                 21
# glutamic-pyruvic transaminase                19
# eGFR                                         19
# creatinine                                   19
# dtype: int64

# %%
#for col in df3.columns: print(col)

# %%
#for col in df3.columns: 
#    if col == 'Lactate dehydrogenase' : 
#        print (col)

# %%
#dropping unusefull atributes 
df3  = df2.drop(["Unnamed: 0",'RE_DATE', 'Admission time','Discharge time'], axis=1)
df3
# Out:
#      PATIENT_ID  age  gender  outcome  hemoglobin  Serum chloride  \
# 0             1   73       1        0  133.200000      100.220000
# 1             2   61       1        0  145.750000       99.275000
# 2             3   70       2        0  115.666667      101.400000
# 3             4   74       1        0   98.000000      101.950000
# 4             5   29       2        0  128.000000      100.950000
# ..          ...  ...     ...      ...         ...             ...
# 370         371   63       1        1  143.000000       95.700000
# 371         372   79       1        1  118.700000      119.609091
# 372         373   61       2        1  100.000000      102.600000
# 373         374   33       1        1  119.000000      124.033333
# 374         375   68       1        1  163.000000       99.725000
#
#      eosinophils(%)  Alkaline phosphatase    albumin  basophil(%)  ...  \
# 0          0.780000             57.800000  34.480000     0.200000  ...
# 1          0.050000             41.500000  35.950000     0.175000  ...
# 2          0.100000             59.000000  35.766667     0.100000  ...
# 3          2.100000             72.500000  34.000000     0.200000  ...
# 4          2.166667             81.000000  39.850000     0.333333  ...
# ..              ...                   ...        ...          ...  ...
# 370        0.000000             65.000000  30.700000     0.000000  ...
# 371        0.240000            132.888889  21.122222     0.230000  ...
# 372        0.100000            141.000000  23.900000     0.100000  ...
# 373        0.000000            137.000000  27.266667     0.250000  ...
# 374        0.000000             82.000000  26.933333     0.300000  ...
#
#      monocytes count   globulin  γ-glutamyl transpeptidase  basophil count(#)  \
# 0           0.614000  32.380000                  33.000000           0.016000
# 1           0.495000  35.650000                  46.000000           0.017500
# 2           0.343333  30.466667                  42.666667           0.006667
# 3           0.515000  31.650000                  14.500000           0.012500
# 4           0.440000  30.450000                  20.000000           0.023333
# ..               ...        ...                        ...                ...
# 370         0.280000  33.300000                  27.000000           0.000000
# 371         0.698000  31.588889                 215.444444           0.038000
# 372         0.550000  36.900000                  39.000000           0.010000
# 373         0.325000  29.333333                 175.666667           0.035000
# 374         0.205000  30.433333                  36.000000           0.025000
#
#      mean corpuscular hemoglobin  Hypersensitive c-reactive protein  \
# 0                      32.120000                          16.433333
# 1                      32.000000                          27.400000
# 2                      31.833333                          22.950000
# 3                      41.725000                          61.350000
# 4                      29.866667                           3.900000
# ..                           ...                                ...
# 370                    30.400000                         152.000000
# 371                    30.010000                         232.187500
# 372                    27.600000                         205.800000
# 373                    30.150000                         109.800000
# 374                    31.550000                         162.750000
#
#      serum sodium  glutamic-pyruvic transaminase        eGFR  creatinine
# 0      140.540000                      29.200000   66.700000   99.000000
# 1      138.225000                      29.000000   90.400000   79.250000
# 2      139.766667                      56.666667   83.933333   63.666667
# 3      141.050000                      23.000000   78.100000   84.500000
# 4      141.900000                      15.000000  121.400000   56.000000
# ..            ...                            ...         ...         ...
# 370    135.800000                      31.000000   88.600000   81.000000
# 371    153.636364                      82.444444   16.818182  297.363636
# 372    141.600000                       9.000000  101.300000   47.000000
# 373    160.400000                    1061.000000   80.933333  109.333333
# 374    135.600000                      17.666667   76.500000   91.000000
#
# [375 rows x 45 columns]

# %%
#col_means = df3.mean()
#col_means
#filling na values with the column mean 
df_final = df3.fillna(df3.mean())
df_final
# Out:
#      PATIENT_ID  age  gender  outcome  hemoglobin  Serum chloride  \
# 0             1   73       1        0  133.200000      100.220000
# 1             2   61       1        0  145.750000       99.275000
# 2             3   70       2        0  115.666667      101.400000
# 3             4   74       1        0   98.000000      101.950000
# 4             5   29       2        0  128.000000      100.950000
# ..          ...  ...     ...      ...         ...             ...
# 370         371   63       1        1  143.000000       95.700000
# 371         372   79       1        1  118.700000      119.609091
# 372         373   61       2        1  100.000000      102.600000
# 373         374   33       1        1  119.000000      124.033333
# 374         375   68       1        1  163.000000       99.725000
#
#      eosinophils(%)  Alkaline phosphatase    albumin  basophil(%)  ...  \
# 0          0.780000             57.800000  34.480000     0.200000  ...
# 1          0.050000             41.500000  35.950000     0.175000  ...
# 2          0.100000             59.000000  35.766667     0.100000  ...
# 3          2.100000             72.500000  34.000000     0.200000  ...
# 4          2.166667             81.000000  39.850000     0.333333  ...
# ..              ...                   ...        ...          ...  ...
# 370        0.000000             65.000000  30.700000     0.000000  ...
# 371        0.240000            132.888889  21.122222     0.230000  ...
# 372        0.100000            141.000000  23.900000     0.100000  ...
# 373        0.000000            137.000000  27.266667     0.250000  ...
# 374        0.000000             82.000000  26.933333     0.300000  ...
#
#      monocytes count   globulin  γ-glutamyl transpeptidase  basophil count(#)  \
# 0           0.614000  32.380000                  33.000000           0.016000
# 1           0.495000  35.650000                  46.000000           0.017500
# 2           0.343333  30.466667                  42.666667           0.006667
# 3           0.515000  31.650000                  14.500000           0.012500
# 4           0.440000  30.450000                  20.000000           0.023333
# ..               ...        ...                        ...                ...
# 370         0.280000  33.300000                  27.000000           0.000000
# 371         0.698000  31.588889                 215.444444           0.038000
# 372         0.550000  36.900000                  39.000000           0.010000
# 373         0.325000  29.333333                 175.666667           0.035000
# 374         0.205000  30.433333                  36.000000           0.025000
#
#      mean corpuscular hemoglobin  Hypersensitive c-reactive protein  \
# 0                      32.120000                          16.433333
# 1                      32.000000                          27.400000
# 2                      31.833333                          22.950000
# 3                      41.725000                          61.350000
# 4                      29.866667                           3.900000
# ..                           ...                                ...
# 370                    30.400000                         152.000000
# 371                    30.010000                         232.187500
# 372                    27.600000                         205.800000
# 373                    30.150000                         109.800000
# 374                    31.550000                         162.750000
#
#      serum sodium  glutamic-pyruvic transaminase        eGFR  creatinine
# 0      140.540000                      29.200000   66.700000   99.000000
# 1      138.225000                      29.000000   90.400000   79.250000
# 2      139.766667                      56.666667   83.933333   63.666667
# 3      141.050000                      23.000000   78.100000   84.500000
# 4      141.900000                      15.000000  121.400000   56.000000
# ..            ...                            ...         ...         ...
# 370    135.800000                      31.000000   88.600000   81.000000
# 371    153.636364                      82.444444   16.818182  297.363636
# 372    141.600000                       9.000000  101.300000   47.000000
# 373    160.400000                    1061.000000   80.933333  109.333333
# 374    135.600000                      17.666667   76.500000   91.000000
#
# [375 rows x 45 columns]

# %%
df_final
# Out:
#      PATIENT_ID  age  gender  outcome  Hypersensitive cardiac troponinI  \
# 0             1   73       1        0                         19.900000
# 1             2   61       1        0                          6.900000
# 2             3   70       2        0                        765.964278
# 3             4   74       1        0                          4.800000
# 4             5   29       2        0                          5.600000
# ..          ...  ...     ...      ...                               ...
# 370         371   63       1        1                       1741.500000
# 371         372   79       1        1                         30.716667
# 372         373   61       2        1                        124.800000
# 373         374   33       1        1                        372.400000
# 374         375   68       1        1                         48.050000
#
#      hemoglobin  Serum chloride  Prothrombin time  procalcitonin  \
# 0    133.200000      100.220000         13.466667       0.090000
# 1    145.750000       99.275000         13.300000       0.090000
# 2    115.666667      101.400000         13.600000       0.060000
# 3     98.000000      101.950000         16.300000       0.380000
# 4    128.000000      100.950000         14.600000       0.020000
# ..          ...             ...               ...            ...
# 370  143.000000       95.700000         14.400000       1.510000
# 371  118.700000      119.609091         17.916667       1.635000
# 372  100.000000      102.600000         14.900000       0.560000
# 373  119.000000      124.033333         23.250000       0.880558
# 374  163.000000       99.725000         14.950000       1.455000
#
#      eosinophils(%)  ...  mean corpuscular hemoglobin  \
# 0          0.780000  ...                    32.120000
# 1          0.050000  ...                    32.000000
# 2          0.100000  ...                    31.833333
# 3          2.100000  ...                    41.725000
# 4          2.166667  ...                    29.866667
# ..              ...  ...                          ...
# 370        0.000000  ...                    30.400000
# 371        0.240000  ...                    30.010000
# 372        0.100000  ...                    27.600000
# 373        0.000000  ...                    30.150000
# 374        0.000000  ...                    31.550000
#
#      Activation of partial thromboplastin time  \
# 0                                    38.400000
# 1                                    39.150000
# 2                                    34.800000
# 3                                    40.908918
# 4                                    40.908918
# ..                                         ...
# 370                                  43.800000
# 371                                  47.816667
# 372                                  36.700000
# 373                                  38.700000
# 374                                  40.600000
#
#      Hypersensitive c-reactive protein  HIV antibody quantification  \
# 0                            16.433333                     0.090000
# 1                            27.400000                     0.099745
# 2                            22.950000                     0.100000
# 3                            61.350000                     0.110000
# 4                             3.900000                     0.080000
# ..                                 ...                          ...
# 370                         152.000000                     0.099745
# 371                         232.187500                     0.060000
# 372                         205.800000                     0.099745
# 373                         109.800000                     0.090000
# 374                         162.750000                     0.080000
#
#      serum sodium  thrombocytocrit        ESR  glutamic-pyruvic transaminase  \
# 0      140.540000         0.170000  41.000000                      29.200000
# 1      138.225000         0.317500  40.000000                      29.000000
# 2      139.766667         0.240000  47.500000                      56.666667
# 3      141.050000         0.207500  72.000000                      23.000000
# 4      141.900000         0.316667  13.000000                      15.000000
# ..            ...              ...        ...                            ...
# 370    135.800000         0.160000  19.000000                      31.000000
# 371    153.636364         0.172000  93.000000                      82.444444
# 372    141.600000         0.180000  33.867593                       9.000000
# 373    160.400000         0.130000  19.000000                    1061.000000
# 374    135.600000         0.240000  39.000000                      17.666667
#
#            eGFR  creatinine
# 0     66.700000   99.000000
# 1     90.400000   79.250000
# 2     83.933333   63.666667
# 3     78.100000   84.500000
# 4    121.400000   56.000000
# ..          ...         ...
# 370   88.600000   81.000000
# 371   16.818182  297.363636
# 372  101.300000   47.000000
# 373   80.933333  109.333333
# 374   76.500000   91.000000
#
# [375 rows x 68 columns]

# %%
#df4 = df3.dropna(axis=1, how='any')
#df4
#constucting X and y 
X = df_final.drop(["PATIENT_ID",'outcome'], axis=1)
y= df_final['outcome']
X.shape
# Out:
# (375, 43)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn.linear_model import LogisticRegression

#splitting the dataset to train and test sets 
X_train, X_test, y_train, y_test = train_test_split(X , y, test_size=0.3, random_state=0)

logreg = LogisticRegression(solver='lbfgs', max_iter=10000, random_state=0)
logreg = logreg.fit(X_train, y_train)

#making a prediction
y_pred= logreg.predict(X_test)

#print (clf.predict_proba(y_test))

#clf.score(X_train, y_train)
#?#how to do regression in non numerical values

print('Test accuracy of the model:' , logreg.score(X_test, y_test), "\n")

print('Classification report:',"\n", classification_report(y_test, y_pred))
# Out:
# Test accuracy of the model: 0.9469026548672567
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95        60
#            1       0.96      0.92      0.94        53
#
#     accuracy                           0.95       113
#    macro avg       0.95      0.95      0.95       113
# weighted avg       0.95      0.95      0.95       113

# %%
#implementing 5-fold cross validation
from sklearn.model_selection import cross_val_score

scores = cross_val_score(logreg, X, y, cv=5, scoring= 'accuracy')
print('Cross Validation accuracy scores:', scores)
print('Mean of Cross Validation scores:', scores.mean())
# Out:
# Cross Validation accuracy scores: [0.96       0.90666667 0.96       0.90666667 0.84      ]
# Mean of Cross Validation scores: 0.9146666666666666

# %%
#modify thresshold based on the optimal fundings of the ROC curve  
proba = logreg.predict_proba(X_test)[:,1]
# print (proba.size)

y_pred_thres2= [None for _ in range(proba.size)]

for i in range(75):
    if proba[i] >= 0.452030 : 
        y_pred_thres2[i]=1
        #y_pred2[i].append(y_pred2)
    else:
        y_pred_thres2[i]=0
        #y_pred2.append(y_pred2)

y_pred_thres2

print(classification_report(y_test, y_pred_thres2))
# Out:
# 113
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-5c81fb41c36e> in <module>
#      14 y_pred_thres2
#      15
# ---> 16 print(classification_report(y_test, y_pred_thres2))
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    1927     """
#    1928
# -> 1929     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1930
#    1931     labels_given = True
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      88
#      89     if len(y_type) > 1:
# ---> 90         raise ValueError("Classification metrics can't handle a mix of {0} "
#      91                          "and {1} targets".format(type_true, type_pred))
#      92
#
# ValueError: Classification metrics can't handle a mix of binary and unknown targets

# %% [markdown]
# ### Finding the optimal threshold via ROC curve

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

fpr, tpr, thresholds = roc_curve(y_test, proba)
thresholds
# Out:
# array([2.00000000e+00, 1.00000000e+00, 1.00000000e+00, 9.99999998e-01,
#        9.99999985e-01, 9.99991148e-01, 9.99966371e-01, 9.99935318e-01,
#        9.99836004e-01, 4.94018753e-01, 3.54172246e-07, 2.03897399e-07,
#        2.20001476e-20])

# %%
import numpy as np

from sklearn.metrics import accuracy_score
accuracy_ls = []
for thres in thresholds:
    y_pred = np.where(proba>thres,1,0)
    accuracy_ls.append(accuracy_score(y_test, y_pred, normalize=True))
    
accuracy_ls = pd.concat([pd.Series(thresholds), pd.Series(accuracy_ls)],
                        axis=1)
accuracy_ls.columns = ['thresholds', 'accuracy']
accuracy_ls.sort_values(by='accuracy', ascending=False, inplace=True)
accuracy_ls.head()
# Out:
#    thresholds  accuracy
# 9    0.494019  0.946903
# 6    0.999966  0.867257
# 8    0.999836  0.867257
# 5    0.999991  0.858407
# 7    0.999935  0.858407

# %%
import matplotlib.pyplot as plt

def plot_roc_curve(fpr, tpr):
    plt.plot(fpr, tpr, color='orange', label='ROC')
    plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend()
    plt.show()
    
plot_roc_curve(fpr,tpr)

# %%
#logreg.predict_proba(X_test)

# %%
print(classification_report(y_test, y_pred_thres2))

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import matplotlib.pyplot as plt

clf = DecisionTreeClassifier(max_depth=4,random_state=0) #max_depth=7,

clf = clf.fit(X_train ,y_train)

#print ('train accuracy:', clf.score(X_train, y_train))
print ('Test accuracy:', clf.score(X_test, y_test))

y_pred_tree = clf.predict(X_test)

print('Classification report:',"\n", classification_report(y_test, y_pred_tree))

tree.plot_tree(clf, filled = True, fontsize = 7) 
plt.show()
# Out:
# Test accuracy: 0.911504424778761
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91        60
#            1       0.88      0.94      0.91        53
#
#     accuracy                           0.91       113
#    macro avg       0.91      0.91      0.91       113
# weighted avg       0.91      0.91      0.91       113

# %%
#implementing 5-fold cross validation for the decission tree
scores = cross_val_score(clf, X, y, cv=5, scoring= 'accuracy')
print('Cross Validation accuracy scores:', scores)
print('Mean of Cross Validation scores:', scores.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-f27b9650494a> in <module>
#       1 #implementing 5-fold cross validation for the decission tree
# ----> 2 scores = cross_val_score(clf, X, y, cv=5, scoring= 'accuracy')
#       3 print('Cross Validation accuracy scores:', scores)
#       4 print('Mean of Cross Validation scores:', scores.mean())
#
# NameError: name 'clf' is not defined

# %% [markdown]
# ### AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

adaboost = AdaBoostClassifier(random_state=0)
adaboost.fit(X_train, y_train)

adaboost.predict(X_test)

print ('Test accuracy:', adaboost.score(X_test, y_test),"\n")

y_pred_adaboost = adaboost.predict(X_test)

print('Classification report:',"\n", classification_report(y_test, y_pred_adaboost))
# Out:
# Test accuracy: 0.9823008849557522
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        60
#            1       0.98      0.98      0.98        53
#
#     accuracy                           0.98       113
#    macro avg       0.98      0.98      0.98       113
# weighted avg       0.98      0.98      0.98       113

# %%
scores = cross_val_score(adaboost, X, y, cv=5, scoring= 'accuracy')
print('Cross Validation accuracy scores:', scores)
print('Mean of Cross Validation scores:', scores.mean())
# Out:
# Cross Validation accuracy scores: [0.94666667 0.92       0.98666667 0.93333333 0.86666667]
# Mean of Cross Validation scores: 0.9306666666666669

# %% [markdown]
# ## PCA TEST

# %%
#how many components to get X of the explained variane
pca=PCA(0.99)
pca_dim_reducts = pca.fit_transform(X)
pca_regenerations = pca.inverse_transform(pca_dim_reducts)
print(pca.explained_variance_.shape[0])
# Out:
# 2

# %%
# This code is given
from numpy import array
from sklearn.decomposition import PCA

# define a matrix
#A = array([[1, 2], [3, 4], [5, 6]])
#print(A)

# create the PCA instance
pca = PCA(n_components=3)

# fit on data
pca.fit(X)
'''
# access values and vectors
print(pca.components_)
print(pca.explained_variance_)

# transform data
B = pca.transform(X)
print(B)
'''
print(pca.explained_variance_)
# Out:
# [45023182.11036629 11979596.73045393   104323.85663163]

# %%
pca = PCA(2)  # project from 64 to 2 dimensions
projected = pca.fit_transform(X)
print(X.shape)
print(projected.shape)

plt.scatter(projected[:, 0], projected[:, 1],
            c=y, edgecolor='none', alpha=0.5,)
plt.xlabel('component 1')
plt.ylabel('component 2')
plt.colorbar();
# Out:
# (375, 66)
# (375, 2)

# %%
pca = PCA().fit(X)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %%
pca.n_components = 3
X_reduced = pca.fit_transform(X)
pca.get_params()
# Out:
# {'copy': True,
#  'iterated_power': 'auto',
#  'n_components': 3,
#  'random_state': None,
#  'svd_solver': 'auto',
#  'tol': 0.0,
#  'whiten': False}

# %%
data_scaled = pd.DataFrame(preprocessing.scale(X),columns = df.columns) 
data_scaled

# %%
import pandas as pd
import pylab as pl
from sklearn import datasets
from sklearn.decomposition import PCA

# load dataset

# normalize data
from sklearn import preprocessing
data_scaled = pd.DataFrame(preprocessing.scale(X),columns = X.columns) 

# PCA
pca = PCA(n_components=3)
pca.fit_transform(X.T)

# Dump components relations with features:
df_pca = pd.DataFrame(pca.components_,columns=data_scaled.columns,index = ['PC-1','PC-2','PC-3'])
df_pca.head()

# %%
#plt.scatter(X['Lactate_dehydrogenase'],y)
#plt.show()
pca_regenerations.shape

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA

pca = PCA(n_components=3)
pca.fit(X.T)

pca.components_

# %% [markdown]
# =================================================================

# %%
from sklearn.neural_network import MLPClassifier
X = [[0., 0.], [1., 1.]]
y = [0, 1]
clf = MLPClassifier(solver='lbfgs', alpha=1e-5,
                    hidden_layer_sizes=(5, 2), random_state=1)

clf.fit(X, y)

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

regr = MLPRegressor(random_state=1, max_iter=1000).fit(X_train, y_train)
#regr.predict(X_test[:2])

print(regr.score(X_test, y_test))

# %% [markdown]
# =================================================================

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()

y_pred = gnb.fit(X_train, y_train).predict(X_test)

print("Number of mislabeled points out of a total %d points : %d"
      % (X_test.shape[0], (y_test != y_pred).sum()))

# %% [markdown]
# ================================================================= SVM

# %%
    for C in Cs:
        if (kernel=='linear'):
            model=svm.SVC(kernel='linear', C=C)
            model.fit(X,y)
            y_pred = model.predict(X)
            accuracy=accuracy_score(y, y_pred)
            models.append(model)
            titles.append('K('+kernel+') C='+str(C)+' Acc='+str(round(accuracy,2)))
            
        else:
            for gamma in gammas:
                model=svm.SVC(kernel=kernel, gamma=gamma, C=C)
                model.fit(X,y)
                y_pred = model.predict(X)
                accuracy=accuracy_score(y, y_pred)
                models.append(model)
                titles.append('K('+kernel+') C='+str(C)+' $\gamma$='+str(gamma)+' Acc='+str(round(accuracy,2)))

# %%
import numpy as np
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import accuracy_score

from sklearn.svm import SVC

#svm_model = make_pipeline(StandardScaler(), SVC(gamma='auto'))
svm_model =svm.SVC(kernel='linear',  C=100)

svm_model.fit(X_train, y_train)
print ('Test accuracy:', svm_model.score(X_test, y_test))

# %%
scores = cross_val_score(svm_model, X, y, cv=5, scoring= 'accuracy')
print('Cross Validation accuracy scores:', scores)
print('Mean of Cross Validation scores:', scores.mean())

# %% [markdown]
# =================================================================

# %% [markdown]
# ================================================================= Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
ytrain_pred = rf_model.predict_proba(X_train)
print('RF train roc-auc: {}'.format(roc_auc_score(y_train, ytrain_pred[:,1])))
ytest_pred = rf_model.predict_proba(X_test)
print('RF test roc-auc: {}'.format(roc_auc_score(y_test, ytest_pred[:,1])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-dcc1c3388e18> in <module>
#       3 rf_model.fit(X_train, y_train)
#       4 ytrain_pred = rf_model.predict_proba(X_train)
# ----> 5 print('RF train roc-auc: {}'.format(roc_auc_score(y_train, ytrain_pred[:,1])))
#       6 ytest_pred = rf_model.predict_proba(X_test)
#       7 print('RF test roc-auc: {}'.format(roc_auc_score(y_test, ytest_pred[:,1])))
#
# NameError: name 'roc_auc_score' is not defined

# %%
rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
ytrain_pred = rf_model.predict_proba(X_train)

#print (clf.predict_proba(y_test))

#clf.score(X_train, y_train)
#?#how to do regression in non numerical values
print(classification_report(y_test, ytrain_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-3510f394b477> in <module>
#       7 #clf.score(X_train, y_train)
#       8 #?#how to do regression in non numerical values
# ----> 9 print(classification_report(y_test, ytrain_pred))
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    1927     """
#    1928
# -> 1929     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1930
#    1931     labels_given = True
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      79     y_pred : array or indicator matrix
#      80     """
# ---> 81     check_consistent_length(y_true, y_pred)
#      82     type_true = type_of_target(y_true)
#      83     type_pred = type_of_target(y_pred)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     253     uniques = np.unique(lengths)
#     254     if len(uniques) > 1:
# --> 255         raise ValueError("Found input variables with inconsistent numbers of"
#     256                          " samples: %r" % [int(l) for l in lengths])
#     257
#
# ValueError: Found input variables with inconsistent numbers of samples: [113, 262]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

scores = cross_val_score(rf_model, X, y, cv=5, scoring= 'accuracy')
print('Cross Validation accuracy scores:', scores)
print('Mean of Cross Validation scores:', scores.mean())
# Out:
# Cross Validation accuracy scores: [0.98666667 0.97333333 0.94666667 0.97333333 0.84      ]
# Mean of Cross Validation scores: 0.944

# %% [markdown]
# =================================================================

# %%
conda create -n newenvt anaconda python=3.5
activate newenvt
# Out:
#   File "<ipython-input-15-1605b66b86ff>", line 1
#     conda create -n newenvt anaconda python=3.5
#           ^
# SyntaxError: invalid syntax

# %%
import tensorflow.keras as keras
import tensorflow as tf
x_trainNN = tf.keras.utils.normalize(x_train, axis=1)
x_testNN = tf.keras.utils.normalize(x_test, axis=1)

# %% [markdown]
# =================================================================

# %% [markdown]
# =================================================================

# %% [markdown]
# =================================================================

# %% [markdown]
# =================================================================

# %% [markdown]
# =================================================================

# %% [markdown]
# =================================================================

# %%
from sklearn.linear_model import LogisticRegression
log_classifier=LogisticRegression()
log_classifier.fit(X_train, y_train)
ytrain_pred = log_classifier.predict_proba(X_train)
print('Logistic train roc-auc: {}'.format(roc_auc_score(y_train, ytrain_pred[:,1])))
ytest_pred = log_classifier.predict_proba(X_test)
print('Logistic test roc-auc: {}'.format(roc_auc_score(y_test, ytest_pred[:,1])))
# Out:
# Logistic train roc-auc: 0.9947718843558693
# Logistic test roc-auc: 0.9592857142857143
# C:\Users\gougo\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# =================================================================

# %%
#X = pd.concat([pari , births['age_cat'] ,etni, births['urban']] ,axis = 'columns')

# %%
'''from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer

ohe =  OneHotEncoder(sparse = False)
#ohe =  OneHotEncoder() 

column_trans= make_column_transformer((OneHotEncoder(), ['parity', 'age_cat', 'etnicity', 'urban']), remainder = 'passthrough')
X = column_trans.fit_transform(X)
X
'''

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

scores = cross_val_score(logreg, X, home, cv=5, scoring= 'accuracy')
print('mean of Cross Validation scores:', scores.mean())

# %%
from sklearn import tree

clf = tree.DecisionTreeClassifier(max_depth=3, random_state=0)

clf = clf.fit(X_train ,y_train)

tree.plot_tree(clf, filled = True, fontsize = 7) 

#plt.show()

print ('train accuracy:', clf.score(X_test, y_test))
print ('test accuracy:', clf.score(X_train, y_train))

#fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=300)
#clf.savefig('Users\gougo\Documents\Twente\1B\Data science\DM\imagename.png')

# %%
models = [
    ('Logistic Regression accuracy:',LogisticRegression(random_state=0)),
    ('Decision Tree accuracy:', tree.DecisionTreeClassifier(max_depth=3, random_state=0)),
]

# we have already used sklearn.model_selection to train/test split our dataset so we dont need to do it again

for name, model in models:
        clf = model
        clf.fit(X_train, y_train)
        accuracy = clf.score(X_test, y_test)
        print(name, accuracy)

# %%
#we have awlready inported and used cross_val_score so we dont need to do it again 
scoresLR = cross_val_score(logreg, X, home, cv=5, scoring= 'accuracy')
print('mean of Cross Validation scores:', scoresLR.mean()) 

scoresDT = cross_val_score(clf, X, home, cv=5, scoring= 'accuracy')
print('mean of Decision Tree scores:', scoresDT.mean())
